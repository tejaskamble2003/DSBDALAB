# %%
# Perform the following operations using Python on the Facebook metrics data sets
# a. Create data subsets
# b. Merge Data
# c. Sort Data
# d. Transposing Data
# e. Shape and reshape Data

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/facebook.csv',sep=';')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
sub1=df[['Type','Category','Post Month','Post Weekday']].loc[0:15]

# %%
sub1
# Out:
#       Type  Category  Post Month  Post Weekday
# 0    Photo         2          12             4
# 1   Status         2          12             3
# 2    Photo         3          12             3
# 3    Photo         2          12             2
# 4    Photo         2          12             2
# 5   Status         2          12             1
# 6    Photo         3          12             1
# 7    Photo         3          12             7
# 8   Status         2          12             7
# 9    Photo         3          12             6
# 10  Status         2          12             5
# 11   Photo         2          12             5
# 12   Photo         2          12             5
# 13   Photo         2          12             5
# 14   Photo         2          12             4
# 15  Status         2          12             3

# %%
sub2=df[['Type','Category','Post Month','Post Weekday']].loc[16:30]

# %%
sub2
# Out:
#       Type  Category  Post Month  Post Weekday
# 16   Photo         3          12             3
# 17   Photo         1          12             2
# 18  Status         3          12             2
# 19   Photo         3          12             1
# 20   Photo         2          12             1
# 21   Photo         1          12             7
# 22    Link         1          12             7
# 23   Photo         3          12             7
# 24  Status         2          12             6
# 25  Status         2          12             6
# 26  Status         2          12             5
# 27   Photo         3          12             5
# 28   Photo         2          12             5
# 29   Video         1          12             4
# 30   Photo         2          12             4

# %%
mergedata=pd.concat([sub1,sub2])
mergedata
# Out:
#       Type  Category  Post Month  Post Weekday
# 0    Photo         2          12             4
# 1   Status         2          12             3
# 2    Photo         3          12             3
# 3    Photo         2          12             2
# 4    Photo         2          12             2
# 5   Status         2          12             1
# 6    Photo         3          12             1
# 7    Photo         3          12             7
# 8   Status         2          12             7
# 9    Photo         3          12             6
# 10  Status         2          12             5
# 11   Photo         2          12             5
# 12   Photo         2          12             5
# 13   Photo         2          12             5
# 14   Photo         2          12             4
# 15  Status         2          12             3
# 16   Photo         3          12             3
# 17   Photo         1          12             2
# 18  Status         3          12             2
# ...

# %%
sub3=df[100:110]
sub3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 100            137020   Photo         1          10             4          9
# 101            137020   Photo         2          10             4          3
# 102            137020   Photo         3          10             3         10
# 103            137020   Photo         1          10             3          4
# 104            137020   Photo         1          10             2         11
# 105            137020   Photo         1          10             2          4
# 106            137020   Photo         3          10             1         11
# 107            136736  Status         2          10             1          4
# 108            136736   Photo         3          10             7          9
# 109            136736  Status         2          10             7          3
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# ...

# %%
sub4=df.loc[110:115]
sub4
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 110            136736  Photo         1          10             6         10
# 111            136736  Photo         1          10             6          8
# 112            136736  Photo         2          10             6          4
# 113            136642  Photo         2          10             1          3
# 114            136642  Photo         1          10             7         13
# 115            136642  Photo         1          10             7         12
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 110   0.0                       1673                             3655
# 111   0.0                       1261                             2158
# 112   0.0                       2428                             4510
# 113   1.0                       2227                             4070
# 114   0.0                       1592                             2749
# ...

# %%
md=pd.merge(sub3,sub4,on="Category")
md
# Out:
#     Page total likes_x  Type_x  Category  Post Month_x  Post Weekday_x  \
# 0               137020   Photo         1            10               4
# 1               137020   Photo         1            10               4
# 2               137020   Photo         1            10               4
# 3               137020   Photo         1            10               4
# 4               137020   Photo         1            10               3
# 5               137020   Photo         1            10               3
# 6               137020   Photo         1            10               3
# 7               137020   Photo         1            10               3
# 8               137020   Photo         1            10               2
# 9               137020   Photo         1            10               2
# 10              137020   Photo         1            10               2
# 11              137020   Photo         1            10               2
# ...

# %%
td=df.T
td
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
td1=sub1.transpose()
td1
# Out:
#                  0       1      2      3      4       5      6      7   \
# Type          Photo  Status  Photo  Photo  Photo  Status  Photo  Photo
# Category          2       2      3      2      2       2      3      3
# Post Month       12      12     12     12     12      12     12     12
# Post Weekday      4       3      3      2      2       1      1      7
#
#                   8      9       10     11     12     13     14      15
# Type          Status  Photo  Status  Photo  Photo  Photo  Photo  Status
# Category           2      3       2      2      2      2      2       2
# Post Month        12     12      12     12     12     12     12      12
# Post Weekday       7      6       5      5      5      5      4       3

# %%
sub1
# Out:
#       Type  Category  Post Month  Post Weekday
# 0    Photo         2          12             4
# 1   Status         2          12             3
# 2    Photo         3          12             3
# 3    Photo         2          12             2
# 4    Photo         2          12             2
# 5   Status         2          12             1
# 6    Photo         3          12             1
# 7    Photo         3          12             7
# 8   Status         2          12             7
# 9    Photo         3          12             6
# 10  Status         2          12             5
# 11   Photo         2          12             5
# 12   Photo         2          12             5
# 13   Photo         2          12             5
# 14   Photo         2          12             4
# 15  Status         2          12             3

# %%
sortdata=sub1.sort_values('Post Weekday', ascending=False)
sortdata
# Out:
#       Type  Category  Post Month  Post Weekday
# 7    Photo         3          12             7
# 8   Status         2          12             7
# 9    Photo         3          12             6
# 10  Status         2          12             5
# 11   Photo         2          12             5
# 12   Photo         2          12             5
# 13   Photo         2          12             5
# 0    Photo         2          12             4
# 14   Photo         2          12             4
# 1   Status         2          12             3
# 2    Photo         3          12             3
# 15  Status         2          12             3
# 3    Photo         2          12             2
# 4    Photo         2          12             2
# 5   Status         2          12             1
# 6    Photo         3          12             1

# %%
sortdata=sub1.sort_values('Post Weekday')
sortdata
# Out:
#       Type  Category  Post Month  Post Weekday
# 5   Status         2          12             1
# 6    Photo         3          12             1
# 3    Photo         2          12             2
# 4    Photo         2          12             2
# 1   Status         2          12             3
# 2    Photo         3          12             3
# 15  Status         2          12             3
# 0    Photo         2          12             4
# 14   Photo         2          12             4
# 10  Status         2          12             5
# 11   Photo         2          12             5
# 12   Photo         2          12             5
# 13   Photo         2          12             5
# 9    Photo         3          12             6
# 7    Photo         3          12             7
# 8   Status         2          12             7

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
pd.melt(df)
# Out:
#                 variable   value
# 0       Page total likes  139441
# 1       Page total likes  139441
# 2       Page total likes  139441
# 3       Page total likes  139441
# 4       Page total likes  139441
# ...                  ...     ...
# 9495  Total Interactions      84
# 9496  Total Interactions      75
# 9497  Total Interactions     115
# 9498  Total Interactions     136
# 9499  Total Interactions     119
#
# [9500 rows x 2 columns]

# %%
df.pivot_table(index='Type',columns='Category', values='like')
# Out:
# Category           1           2           3
# Type
# Link       75.650000   32.000000   68.000000
# Photo     126.000000  235.857143  219.753333
# Status    136.333333  182.552632  151.500000
# Video     231.428571         NaN         NaN
